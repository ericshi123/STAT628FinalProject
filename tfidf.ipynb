# %%
import os
import json
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from nltk.stem.snowball import SnowballStemmer
import nltk
stdout = sys.stdout
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
reviews = pd.read_csv("all_chains_cs_reviews.csv")
reviews.head(5)
# Out:
#    Unnamed: 0             business_id     name               address     city  \
# 0          44  c32IpmTXxiDxKYKvhJiSuQ  Popeyes  6000 N Terminal Pkwy  Atlanta
# 1          91  c32IpmTXxiDxKYKvhJiSuQ  Popeyes  6000 N Terminal Pkwy  Atlanta
# 2         131  IpNJfLJ6R3RjZJF_ucGaZA  Popeyes   4932 State Route 46  Sanford
# 3         132  IpNJfLJ6R3RjZJF_ucGaZA  Popeyes   4932 State Route 46  Sanford
# 4         134  IpNJfLJ6R3RjZJF_ucGaZA  Popeyes   4932 State Route 46  Sanford
#
#   state postal_code   latitude  longitude  stars_x  ...  \
# 0    GA       30320  33.640737 -84.429305      3.5  ...
# 1    GA       30320  33.640737 -84.429305      3.5  ...
# 2    FL       32771  28.811882 -81.344261      1.5  ...
# 3    FL       32771  28.811882 -81.344261      1.5  ...
# 4    FL       32771  28.811882 -81.344261      1.5  ...
#
#                                           categories  \
# 0              Fast Food, Chicken Wings, Restaurants
# 1              Fast Food, Chicken Wings, Restaurants
# 2  Chicken Wings, Restaurants, Fast Food, America...
# 3  Chicken Wings, Restaurants, Fast Food, America...
# 4  Chicken Wings, Restaurants, Fast Food, America...
#
#                                                hours               review_id  \
# 0  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...  tr6X_kKyXgnnyOnax5o0Ng
# 1  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...  3EJq4ihQoTVmvTunSP2-RQ
# 2  {'Monday': '10:0-23:0', 'Tuesday': '10:0-23:0'...  4ASda-KRC4gz5n194yHQ1A
# 3  {'Monday': '10:0-23:0', 'Tuesday': '10:0-23:0'...  4v8hM7d-Zu5x5bdsYfxU1A
# 4  {'Monday': '10:0-23:0', 'Tuesday': '10:0-23:0'...  thb_gq39zatj4dEv_iyAbw
#
#                   user_id stars_y useful funny  cool  \
# 0  cZA_G7kIkyIrR15EKXoVFw     1.0      0     0     0
# 1  zKMCLxQnAOXpHJIKMZCI_Q     1.0      5     1     0
# 2  CpRBM-El-mqvbv93lYX5QA     4.0      5     2     4
# 3  ui1vL68Ty9_aeKGtzJNSHg     1.0      1     0     0
# 4  Lk_clm7vulcrkvcBAyO6fg     1.0      0     0     0
#
#                                                 text                 date
# 0  Awful.  Waited in line for 15-20 for a chicken...  2016-05-25 17:00:07
# 1  This is my first time at the Hartsfield Airpor...  2015-06-08 16:13:57
# 2  They weren't ready for the return of the chick...  2019-11-03 17:56:41
# 3  I have being several times there but they neve...  2020-02-04 13:37:25
# 4  I have been trying to get the spicy chicken sa...  2019-12-17 02:20:50
#
# [5 rows x 23 columns]

# %%
reviews.shape
# Out:
# (2424, 23)

# %%
stemmer = SnowballStemmer("english")
reviews['stemmed'] = reviews.text.map(lambda x: ' '.join([stemmer.stem(y) for y in x.split(' ')]))
reviews.stemmed.head()
# Out:
# 0    awful. wait line 15-20 chicken sandwich biscui...
# 1    this first time hartsfield airport i idea serv...
# 2    they readi return chicken. they stop take orde...
# 3    i sever time never chicken sandwich problem ki...
# 4    i tri get spici chicken sandwich last three mo...
# Name: stemmed, dtype: object

# %%
cvec = CountVectorizer(stop_words='english', min_df=1, max_df=.5, ngram_range=(1,2))
cvec
# Out:
# CountVectorizer(max_df=0.5, ngram_range=(1, 2), stop_words='english')

# %%
from itertools import islice
cvec.fit(reviews.stemmed)
list(islice(cvec.vocabulary_.items(), 20))
# Out:
# [('awful', 6031),
#  ('wait', 88921),
#  ('line', 45923),
#  ('15', 418),
#  ('20', 577),
#  ('biscuit', 8002),
#  ('order', 57236),
#  ('bone', 8756),
#  ('staff', 78386),
#  ('50', 1117),
#  ('miser', 52658),
#  ('compar', 16254),
#  ('helpful', 37878),
#  ('unacceptable', 87082),
#  ('awful wait', 6058),
#  ('wait line', 89056),
#  ('line 15', 45930),
#  ('15 20', 421),
#  ('20 chicken', 583),
#  ('sandwich biscuit', 70376)]

# %%
len(cvec.vocabulary_)
# Out:
# 93818

# %%
cvec = CountVectorizer(stop_words='english', min_df=.0025, max_df=.1, ngram_range=(1,2))
cvec.fit(reviews.stemmed)
len(cvec.vocabulary_)
# Out:
# 3206

# %%
cvec_counts = cvec.transform(reviews.stemmed)
print('sparse matrix shape:', cvec_counts.shape)
print('nonzero count:', cvec_counts.nnz)
print('sparsity: %.2f%%' % (100.0 * cvec_counts.nnz / (cvec_counts.shape[0] * cvec_counts.shape[1])))
# Out:
# sparse matrix shape: (2424, 3206)
# nonzero count: 84466
# sparsity: 1.09%

# %%
occ = np.asarray(cvec_counts.sum(axis=0)).ravel().tolist()
counts_df = pd.DataFrame({'term': cvec.get_feature_names(), 'occurrences': occ})
counts_df.sort_values(by='occurrences', ascending=False).head(20)
# Out:
#           term  occurrences
# 355     burger          353
# 3101     wendi          319
# 1294     grill          309
# 3129    window          308
# 2176    pretti          301
# 1748  mcdonald          297
# 2151     popey          283
# 1684     lunch          283
# 1658       lot          281
# 886      everi          281
# 1769      menu          278
# 2812      sure          273
# 3180     wrong          269
# 2929      told          268
# 221        bad          267
# 2220     quick          267
# 1925      open          264
# 351        bun          263
# 2628      sinc          260
# 3013     usual          258

# %%
transformer = TfidfTransformer()
transformed_weights = transformer.fit_transform(cvec_counts)
transformed_weights
# Out:
# <2424x3206 sparse matrix of type '<class 'numpy.float64'>'
# 	with 84466 stored elements in Compressed Sparse Row format>

# %%
weights = np.asarray(transformed_weights.mean(axis=0)).ravel().tolist()
weights_df = pd.DataFrame({'term': cvec.get_feature_names(), 'weight': weights})
weights_df.sort_values(by='weight', ascending=False).head(20)
# Out:
#                     term    weight
# 3101               wendi  0.013571
# 355               burger  0.013127
# 1294               grill  0.012459
# 2151               popey  0.012020
# 2176              pretti  0.011981
# 1684               lunch  0.011490
# 2220               quick  0.011245
# 2589             service  0.011168
# 1748            mcdonald  0.011073
# 3180               wrong  0.010887
# 542                 cold  0.010812
# 351                  bun  0.010766
# 3129              window  0.010699
# 221                  bad  0.010643
# 1295       grill chicken  0.010517
# 2812                sure  0.010356
# 1890              nugget  0.010334
# 886                everi  0.010296
# 478   chicken sandwiches  0.010224
# 1658                 lot  0.010198

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tvec = TfidfVectorizer(min_df=.0025, max_df=.1, stop_words='english')
tvec_weights = tvec.fit_transform(reviews.stemmed.dropna())
weights = np.asarray(tvec_weights.mean(axis=0)).ravel().tolist()
weights_df = pd.DataFrame({'term': tvec.get_feature_names(), 'weight': weights})
weights_df.sort_values(by='weight', ascending=False).head(20)
# Out:
#           term    weight
# 1798     wendi  0.015916
# 754      grill  0.015405
# 231     burger  0.015184
# 1283    pretti  0.014927
# 1260     popey  0.014503
# 1469   service  0.014063
# 990      lunch  0.014010
# 1315     quick  0.013986
# 1842     wrong  0.013511
# 340       cold  0.013136
# 1023  mcdonald  0.012877
# 1812    window  0.012861
# 1119    nugget  0.012829
# 142        bad  0.012732
# 228        bun  0.012680
# 580      everi  0.012469
# 423     crispi  0.012468
# 972   location  0.012367
# 1635      sure  0.012352
# 318      clean  0.012318

# %%
#Popeyes
df1,df2,df3,df4,df5,df6,df7 = [x for _,x in reviews.groupby(reviews.name)]

# %%
dfs = [df1,df2,df3,df4,df5,df6,df7]

# %%
results = []

# %%
for df in dfs:
    #stemming the words
    stemmer = SnowballStemmer("english")
    df['stemmed'] = df.text.map(lambda x: ' '.join([stemmer.stem(y) for y in x.split(' ')]))
    tvec = TfidfVectorizer(min_df=.0025, max_df=.1, stop_words='english')
    tvec_weights = tvec.fit_transform(df.stemmed.dropna())
    weights = np.asarray(tvec_weights.mean(axis=0)).ravel().tolist()
    weights_df = pd.DataFrame({'term': tvec.get_feature_names(), 'weight': weights})
    results.append(weights_df)
    weights_df.sort_values(by='weight', ascending=False).head(20)

# %%
results[1].sort_values(by='weight', ascending=False).head(20)
# Out:
#           term    weight
# 478      salad  0.030864
# 386        new  0.027711
# 335        lie  0.022006
# 593      times  0.020715
# 633       wish  0.020084
# 396      offer  0.019439
# 647       zero  0.019170
# 91   charbroil  0.019073
# 389        nom  0.018908
# 558      super  0.018844
# 540       stay  0.018285
# 510       slab  0.018260
# 94       check  0.017842
# 118       come  0.017773
# 331        let  0.017739
# 627        whi  0.017599
# 408       paid  0.016811
# 152      crisp  0.016703
# 483       sauc  0.016512
# 328       leav  0.016508

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5f5044dc38a0> in <module>
# ----> 1 test['tweet_without_stopwords'] = test['tweet'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
#
# NameError: name 'test' is not defined
