# %%
import os
import json
import sys
import pandas as pd
import matplotlib.pyplot as plt
stdout = sys.stdout

# %%
ls
# Out:
# business.json     review.py         tip.json
# review.json       review_eda.ipynb  user.json

# %%
raw_json = [json.loads(line) for line in open('/Users/xintongshi/Desktop/yelp_dataset/yelp_dataset/review.json', 'r')]

# %%
raw_json[0]
# Out:
# {'review_id': 'lWC-xP3rd6obsecCYsGZRg',
#  'user_id': 'ak0TdVmGKo4pwqdJSTLwWw',
#  'business_id': 'buF9druCkbuXLX526sGELQ',
#  'stars': 4.0,
#  'useful': 3,
#  'funny': 1,
#  'cool': 1,
# ...

# %%
df = pd.DataFrame(raw_json)

# %%
df.head(5)
# Out:
#                 review_id                 user_id             business_id  \
# 0  lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ
# 1  8bFej1QE5LXp4O05qjGqXA  YoVfDbnISlW0f7abNQACIg  RA4V8pr014UyUbDvI-LW2A
# 2  NDhkzczKjLshODbqDoNLSg  eC5evKn1TWDyHCyQAwguUw  _sS2LBIGNT5NQb6PD1Vtjw
# 3  T5fAqjjFooT4V0OeZyuk1w  SFQ1jcnGguO0LYWnbbftAA  0AzLzHfOJgL7ROwhdww2ew
# 4  sjm_uUcQVxab_EeLCqsYLg  0kA0PAJ8QFMeveQWHFqz2A  8zehGz9jnxPqXtOc7KaJxA
#
#    stars  useful  funny  cool  \
# 0    4.0       3      1     1
# 1    4.0       1      0     0
# 2    5.0       0      0     0
# 3    2.0       1      1     1
# 4    4.0       0      0     0
#
#                                                 text                 date
# 0  Apparently Prides Osteria had a rough summer a...  2014-10-11 03:34:02
# 1  This store is pretty good. Not as great as Wal...  2015-07-03 20:38:25
# 2  I called WVM on the recommendation of a couple...  2013-05-28 20:38:06
# ...

# %%
df_chicken = df[df['text'].str.contains('chicken sandwich')]

# %%
df_chicken.shape[0]
# Out:
# 29824

# %%
df_chicken_stars = df_chicken.groupby('business_id').mean()

# %%
df_chicken_count = df_chicken.value_counts('business_id').reset_index(name='count')

# %%
df_chicken_final = pd.merge(df_chicken_stars, df_chicken_count, on='business_id', how='inner')

# %%
df_chicken_final.loc[(df_chicken_final['count'] >= 10)].sort_values(by=(['stars','count']),ascending=False)
# Out:
#                  business_id     stars    useful     funny      cool  count
# 2366  GsNJWGFjP7pzjGuUETexZg  5.000000  2.454545  0.727273  1.090909     11
# 5679  ecV-i8VUC0v9aLaL4gtMBA  4.958333  0.416667  0.083333  0.208333     24
# 7151  qDs6EP3SQt1r5hTsYZ8jWQ  4.937500  3.812500  0.750000  2.750000     16
# 7518  t5N5pk-xQBfpsfM799wJ5A  4.928571  0.857143  0.142857  0.500000     14
# 514   3AGDyk6AdnCAxY8Am2XqAw  4.903226  1.096774  0.193548  0.741935     31
# 5452  d27P-HGCTjuBL3fWjWl7IA  4.900000  0.933333  0.400000  0.666667     60
# 1506  ATaQ4GLQisXA7tylsJobhQ  4.880000  5.160000  2.000000  4.800000     25
# 4859  ZgqcO8DlWXZ2pG1gF2xHDw  4.875000  0.750000  0.062500  0.437500     16
# 1089  7T-LjWMiIo-3X1WzR_YxcA  4.846154  2.769231  1.000000  1.807692     26
# 6391  kDZTaeUaf78Jd25ktX8a8g  4.833333  0.611111  0.500000  0.166667     18
# 2116  EwKnLuWAWT4wD_LOjRdGew  4.833333  2.500000  0.500000  0.583333     12
# ...

# %%
df_chicken.to_csv("chicken_reviews.csv", sep='\t', encoding='utf-8')
